#  '32_10_F.mp4',
#  '34_08_F.mp4',
#  '32_05_T.mp4',
#  '38_04_F.mp4',
#  '30_05_F.mp4',
#  '34_00_T.mp4',
#  '36_01_T.mp4',
#  '31_09_F.mp4',
#  '32_17_F.mp4',
#  '30_08_F.mp4',
#  '38_06_F.mp4',
#  '34_01_T.mp4',
#  '34_09_F.mp4',
#  '35_00_T.mp4',
#  '38_10_F.mp4',
#  '35_02_T.mp4',
#  '37_04_F.mp4',
#  '30_04_F.mp4',
#  '32_20_F.mp4',
#  '32_07_T.mp4',
#  '32_00_T.mp4',
#  '36_10_F.mp4',
#  '31_07_F.mp4',
#  '38_01_T.mp4',
#  '37_06_F.mp4',
#  '32_03_T.mp4',
#  '31_03_T.mp4',
#  '33_01_T.mp4',
#  '35_01_T.mp4',
#  '32_06_T.mp4',
#  '38_09_F.mp4',
#  '33_02_T.mp4',
#  '33_07_F.mp4',
#  '35_09_F.mp4']

# %%
# !pip install opencv-python-headless librosa ffmpeg-python numpy tqdm
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (0.11.0)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.14.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.1.1)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from ffmpeg-python) (1.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from lazy_loader>=0.1->librosa) (24.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.6.15)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Installing collected packages: ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0

# %% [markdown]
# **Preprocessing Code**

# %%
import os
import cv2
import librosa
import numpy as np
import ffmpeg
from pathlib import Path
from tqdm import tqdm

def extract_audio(video_path, output_wav, sr=16000):
    y, _ = librosa.load(video_path, sr=sr, mono=True)
    librosa.output.write_wav(output_wav, y, sr)

def extract_frames(video_path, output_npy, num_frames=30, size=(96, 96)):
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_idxs = np.linspace(0, total_frames - 1, num=num_frames, dtype=int)

    frames = []
    for idx in range(total_frames):
        ret, frame = cap.read()
        if not ret: break
        if idx in frame_idxs:
            frame = cv2.resize(frame, size)
            frame = frame[..., ::-1]  # BGR to RGB
            frame = frame / 255.0  # normalize
            frames.append(frame.transpose(2, 0, 1))  # CxHxW

    cap.release()
    frames = np.stack(frames, axis=0)  # [30, 3, 96, 96]
    frames = frames.transpose(1, 0, 2, 3)  # [3, 30, 96, 96]
    np.save(output_npy, frames)

def preprocess_folder(input_folder, output_folder):
    Path(output_folder).mkdir(parents=True, exist_ok=True)
    video_files = list(Path(input_folder).rglob("*.mp4"))

    for video_path in tqdm(video_files):
        uid = video_path.stem
        out_video_dir = Path(output_folder) / uid
        out_video_dir.mkdir(exist_ok=True, parents=True)

        frames_path = out_video_dir / "frames.npy"
        audio_path = out_video_dir / "audio.wav"

        try:
            extract_frames(str(video_path), str(frames_path))
            extract_audio(str(video_path), str(audio_path))
        except Exception as e:
            print(f"Error with {video_path}: {e}")

# %% [markdown]
# These Paths in Colab Before Running Preprocessing

# %%
train_input = "/content/drive/MyDrive/biovid_dual_auth/dataset/train"
test_input = "/content/drive/MyDrive/biovid_dual_auth/dataset/test-set"

train_output = "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/data/processed/train"
test_output  = "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/data/processed/test"

preprocess_folder(train_input, train_output)
preprocess_folder(test_input, test_output)
# Out:
#   0%|          | 0/457 [00:00<?, ?it/s]/tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#   0%|          | 1/457 [00:17<2:09:35, 17.05s/it]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/train/5_01_T.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#   0%|          | 2/457 [00:18<1:01:14,  8.08s/it]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/train/1_03_T.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#   1%|          | 3/457 [00:20<39:04,  5.16s/it]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/train/3_00_T.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#   1%|          | 4/457 [00:22<28:41,  3.80s/it]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/train/3_05_T.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#   1%|          | 5/457 [00:24<25:38,  3.40s/it]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/train/2_06_F.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#   1%
mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#  95%|█████████▌| 184/193 [00:47<00:02,  3.82it/s]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/test-set/dec6ff8d5837be9d4f48a275b12f601df0404029.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#  96%|█████████▌| 185/193 [00:47<00:02,  3.87it/s]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/test-set/f14804c4caf4659c43f5f5f610a57422db38da07.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#  96%|█████████▋| 186/193 [00:48<00:01,  3.88it/s]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/test-set/722c211e0ab69498cceed3185332d2333ee12966.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#  97%|█████████▋| 187/193 [00:48<00:01,  3.97it/s]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/test-set/f21427ad07a90ff3762584086d44fc39773c0b2b.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#  97%|█████████▋| 188/193 [00:48<00:01,  3.97it/s]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/test-set/b1f00e97e62f7bb56e775e843f8fc43d98a43c45.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#  98%|█████████▊| 189/193 [00:48<00:00,  4.01it/s]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/test-set/e1ad319bb2d1aff61a2349e9ae769d64392f436f.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#  98%|█████████▊| 190/193 [00:49<00:00,  4.06it/s]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/test-set/8917166df42f30b4bcf192dd909a465218f6b709.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#  99%|█████████▉| 191/193 [00:49<00:00,  3.64it/s]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/test-set/871280a0dead09329d9a4ed254f324636041b532.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#  99%|█████████▉| 192/193 [00:49<00:00,  3.57it/s]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/test-set/f32ec658c22797d1b447c82b0dea5b246534da7e.mp4: No librosa attribute output
# /tmp/ipython-input-7-1267668830.py:10: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(video_path, sr=sr, mono=True)
# /usr/local/lib/python3.11/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# 100%|██████████| 193/193 [00:49<00:00,  3.86it/s]
# Error with /content/drive/MyDrive/biovid_dual_auth/dataset/test-set/d25567946ae922eb2b8680d1ec1df3d6f93a8474.mp4: No librosa attribute output

# %%
import os

processed_path = "/content/drive/MyDrive/biovid_dual_auth/data/processed/train"
print("Sample folders found:")
print(os.listdir(processed_path))
# Out:
# Sample folders found:
# ['5_01_T']

# %%
frames_path = f"/content/drive/MyDrive/biovid_dual_auth/data/processed/train/5_01_T/frames.npy"
frames = np.load(frames_path)
print("Shape of frames:", frames.shape)
# Out:
# Shape of frames: (3, 30, 96, 96)

# %%
import glob

all_npy = glob.glob("/content/drive/MyDrive/biovid_dual_auth/data/processed/train/5_01_T/frames.npy", recursive=True)
print("Total .npy files found:", len(all_npy))
print("Example path:", all_npy[0] if all_npy else "None found")
# Out:
# Total .npy files found: 1
# Example path: /content/drive/MyDrive/biovid_dual_auth/data/processed/train/5_01_T/frames.npy

# %%
import subprocess
import librosa
import soundfile as sf

def extract_audio(video_path, output_wav, sr=16000):
    # Step 1: extract raw audio from video using ffmpeg
    tmp_wav = "temp.wav"
    command = [
        "ffmpeg",
        "-i", video_path,
        "-ar", str(sr),
        "-ac", "1",
        "-y", tmp_wav
    ]
    subprocess.run(command, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Step 2: load with librosa to ensure it's in correct shape
    y, _ = librosa.load(tmp_wav, sr=sr)
    sf.write(output_wav, y, sr)

    # Clean up
    os.remove(tmp_wav)

# %%
from models.audio_encoder import AudioEncoder

audio_path = "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/data/processed/train/10_00_T/audio.wav"
audio_encoder = AudioEncoder()
embedding = audio_encoder(audio_path)
print("Audio embedding shape:", embedding.shape)
# Out:
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Using symlink found at '/content/pretrained_models/spkrec-ecapa/hyperparams.yaml'
# INFO:speechbrain.utils.fetching:Fetch custom.py: Fetching from HuggingFace Hub 'speechbrain/spkrec-ecapa-voxceleb' if not cached
# DEBUG:speechbrain.utils.parameter_transfer:Collecting files (or symlinks) for pretraining in pretrained_models/spkrec-ecapa.
# INFO:speechbrain.utils.fetching:Fetch embedding_model.ckpt: Using symlink found at '/content/pretrained_models/spkrec-ecapa/embedding_model.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["embedding_model"] = /content/pretrained_models/spkrec-ecapa/embedding_model.ckpt
# INFO:speechbrain.utils.fetching:Fetch mean_var_norm_emb.ckpt: Using symlink found at '/content/pretrained_models/spkrec-ecapa/mean_var_norm_emb.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["mean_var_norm_emb"] = /content/pretrained_models/spkrec-ecapa/mean_var_norm_emb.ckpt
# INFO:speechbrain.utils.fetching:Fetch classifier.ckpt: Using symlink found at '/content/pretrained_models/spkrec-ecapa/classifier.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["classifier"] = /content/pretrained_models/spkrec-ecapa/classifier.ckpt
# INFO:speechbrain.utils.fetching:Fetch label_encoder.txt: Using symlink found at '/content/pretrained_models/spkrec-ecapa/label_encoder.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["label_encoder"] = /content/pretrained_models/spkrec-ecapa/label_encoder.ckpt
# INFO:speechbrain.utils.parameter_transfer:Loading pretrained files for: embedding_model, mean_var_norm_emb, classifier, label_encoder
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): embedding_model -> /content/pretrained_models/spkrec-ecapa/embedding_model.ckpt
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): mean_var_norm_emb -> /content/pretrained_models/spkrec-ecapa/mean_var_norm_emb.ckpt
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): classifier -> /content/pretrained_models/spkrec-ecapa/classifier.ckpt
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): label_encoder -> /content/pretrained_models/spkrec-ecapa/label_encoder.ckpt
# DEBUG:speechbrain.dataio.encoder:Loaded categorical encoding from /content/pretrained_models/spkrec-ecapa/label_encoder.ckpt
# Audio embedding shape: torch.Size([1, 192])

# %% [markdown]
# # New Section

# %%
train_input = "/content/drive/MyDrive/biovid_dual_auth/dataset/train"
train_output = "/content/drive/MyDrive/biovid_dual_auth/data/processed/train"

preprocess_folder(train_input, train_output)
# Out:
# 100%|██████████| 457/457 [01:58<00:00,  3.84it/s]

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 130.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 12.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 109.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import sys
sys.path.append("/content/drive/MyDrive/biovid_dual_auth/updated_pipeline")

# %%
from models.visual_encoder import VisualEncoder

# %%
import torch
import numpy as np
from models.visual_encoder import VisualEncoder

# Load a sample frames.npy
frames_path = "/content/drive/MyDrive/biovid_dual_auth/data/processed/train/5_01_T/frames.npy"
frames = np.load(frames_path)
frames_tensor = torch.tensor(frames, dtype=torch.float32).unsqueeze(0)  # [1, 3, 30, 96, 96]

# Run through model
model = VisualEncoder()
embedding = model(frames_tensor)  # Output: [1, 256]
print("Visual embedding shape:", embedding.shape)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R3D_18_Weights.KINETICS400_V1`. You can also use `weights=R3D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/r3d_18-b3b3357e.pth" to /root/.cache/torch/hub/checkpoints/r3d_18-b3b3357e.pth
# 100%|██████████| 127M/127M [00:00<00:00, 194MB/s]
# Visual embedding shape: torch.Size([1, 256])

# %% [markdown]
# #  Audio Encoder – ECAPA-TDNN

# %% [markdown]
# Audio Encoder Setup

# %% [markdown]
# Extract 192-dimensional speaker embeddings from each audio.wav file using a pretrained ECAPA-TDNN model.

# %% [markdown]
# | Component     | Description                                          |
# | ------------- | ---------------------------------------------------- |
# | **Framework** | [`speechbrain`](https://speechbrain.readthedocs.io/) |
# | **Model**     | `ECAPA-TDNN` pretrained on VoxCeleb2                 |
# | **Input**     | `.wav` audio (16 kHz mono)                           |
# | **Output**    | `[192]` speaker embedding                            |

# %% [markdown]
#  Install SpeechBrain

# %%
# !pip install speechbrain
# Out:
# Collecting speechbrain
#   Downloading speechbrain-1.0.3-py3-none-any.whl.metadata (24 kB)
# Collecting hyperpyyaml (from speechbrain)
#   Downloading HyperPyYAML-1.2.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from speechbrain) (1.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from speechbrain) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from speechbrain) (24.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from speechbrain) (1.15.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from speechbrain) (0.2.0)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.11/dist-packages (from speechbrain) (2.6.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from speechbrain) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from speechbrain) (4.67.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from speechbrain) (0.33.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->speechbrain) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.9->speechbrain) (1.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->speechbrain) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->speechbrain) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->speechbrain) (1.1.3)
# Collecting ruamel.yaml>=0.17.28 (from hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml-0.18.14-py3-none-any.whl.metadata (24 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.9->speechbrain) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->speechbrain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->speechbrain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->speechbrain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->speechbrain) (2025.6.15)
# Downloading speechbrain-1.0.3-py3-none-any.whl (864 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 864.1/864.1 kB 38.9 MB/s eta 0:00:00
# Downloading HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Downloading ruamel.yaml-0.18.14-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 12.9 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 50.6 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, ruamel.yaml, hyperpyyaml, speechbrain
# Successfully installed hyperpyyaml-1.2.2 ruamel.yaml-0.18.14 ruamel.yaml.clib-0.2.12 speechbrain-1.0.3

# %% [markdown]
# Use the Audio Encoder in Colab

# %%
import glob

all_audio = glob.glob("/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/data/processed/train/10_00_T/audio.wav", recursive=True)
print(f"Total audio files found: {len(all_audio)}")
print("Example file:", all_audio[0] if all_audio else "None found")
# Out:
# Total audio files found: 1
# Example file: /content/drive/MyDrive/biovid_dual_auth/updated_pipeline/data/processed/train/10_00_T/audio.wav

# %% [markdown]
# Gated Multimodal Unit (GMU) Fusion

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

visual_encoder = VisualEncoder().to(device)
fusion_model = GMUFusion().to(device)
audio_encoder = AudioEncoder(device=device)

frames_tensor = frames_tensor.to(device)

with torch.no_grad():
    v_emb = visual_encoder(frames_tensor)
    a_emb = audio_encoder(audio_path)
    a_emb = a_emb.to(device)  # move audio embedding to same device
    score, joint_emb = fusion_model(a_emb, v_emb)

print("Score:", score.item())
print("Joint Embedding Shape:", joint_emb.shape)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R3D_18_Weights.KINETICS400_V1`. You can also use `weights=R3D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Using symlink found at '/content/pretrained_models/spkrec-ecapa/hyperparams.yaml'
# INFO:speechbrain.utils.fetching:Fetch custom.py: Fetching from HuggingFace Hub 'speechbrain/spkrec-ecapa-voxceleb' if not cached
# DEBUG:speechbrain.utils.parameter_transfer:Collecting files (or symlinks) for pretraining in pretrained_models/spkrec-ecapa.
# INFO:speechbrain.utils.fetching:Fetch embedding_model.ckpt: Using symlink found at '/content/pretrained_models/spkrec-ecapa/embedding_model.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["embedding_model"] = /content/pretrained_models/spkrec-ecapa/embedding_model.ckpt
# INFO:speechbrain.utils.fetching:Fetch mean_var_norm_emb.ckpt: Using symlink found at '/content/pretrained_models/spkrec-ecapa/mean_var_norm_emb.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["mean_var_norm_emb"] = /content/pretrained_models/spkrec-ecapa/mean_var_norm_emb.ckpt
# INFO:speechbrain.utils.fetching:Fetch classifier.ckpt: Using symlink found at '/content/pretrained_models/spkrec-ecapa/classifier.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["classifier"] = /content/pretrained_models/spkrec-ecapa/classifier.ckpt
# INFO:speechbrain.utils.fetching:Fetch label_encoder.txt: Using symlink found at '/content/pretrained_models/spkrec-ecapa/label_encoder.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["label_encoder"] = /content/pretrained_models/spkrec-ecapa/label_encoder.ckpt
# INFO:speechbrain.utils.parameter_transfer:Loading pretrained files for: embedding_model, mean_var_norm_emb, classifier, label_encoder
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): embedding_model -> /content/pretrained_models/spkrec-ecapa/embedding_model.ckpt
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): mean_var_norm_emb -> /content/pretrained_models/spkrec-ecapa/mean_var_norm_emb.ckpt
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): classifier -> /content/pretrained_models/spkrec-ecapa/classifier.ckpt
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): label_encoder -> /content/pretrained_models/spkrec-ecapa/label_encoder.ckpt
# DEBUG:speechbrain.dataio.encoder:Loaded categorical encoding from /content/pretrained_models/spkrec-ecapa/label_encoder.ckpt
# Score: 0.07011409848928452
# Joint Embedding Shape: torch.Size([1, 256])

# %% [markdown]
# #  Fusion + Output Head

# %%
import torch
import numpy as np
from models.visual_encoder import VisualEncoder
from models.audio_encoder import AudioEncoder
from models.fusion_head import GMUFusion

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Load models on correct device
visual_encoder = VisualEncoder().to(device)
fusion_model = GMUFusion().to(device)
audio_encoder = AudioEncoder(device=device)  # SpeechBrain uses its own device

# Load input
frames_path = "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/data/processed/train/10_00_T/frames.npy"
audio_path = "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/data/processed/train/10_00_T/audio.wav"

frames = np.load(frames_path)
frames_tensor = torch.tensor(frames, dtype=torch.float32).unsqueeze(0).to(device)  # [1, 3, 30, 96, 96]

# Run inference
with torch.no_grad():
    v_emb = visual_encoder(frames_tensor)  # [1, 256]
    a_emb = audio_encoder(audio_path)      # [1, 192]
    a_emb = a_emb.to(device)               # Ensure same device
    score, joint_emb = fusion_model(a_emb, v_emb)

print("✅ Score:", score.item())
print("✅ Joint Embedding Shape:", joint_emb.shape)
# Out:
# Using device: cuda
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R3D_18_Weights.KINETICS400_V1`. You can also use `weights=R3D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Using symlink found at '/content/pretrained_models/spkrec-ecapa/hyperparams.yaml'
# INFO:speechbrain.utils.fetching:Fetch custom.py: Fetching from HuggingFace Hub 'speechbrain/spkrec-ecapa-voxceleb' if not cached
# DEBUG:speechbrain.utils.parameter_transfer:Collecting files (or symlinks) for pretraining in pretrained_models/spkrec-ecapa.
# INFO:speechbrain.utils.fetching:Fetch embedding_model.ckpt: Using symlink found at '/content/pretrained_models/spkrec-ecapa/embedding_model.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["embedding_model"] = /content/pretrained_models/spkrec-ecapa/embedding_model.ckpt
# INFO:speechbrain.utils.fetching:Fetch mean_var_norm_emb.ckpt: Using symlink found at '/content/pretrained_models/spkrec-ecapa/mean_var_norm_emb.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["mean_var_norm_emb"] = /content/pretrained_models/spkrec-ecapa/mean_var_norm_emb.ckpt
# INFO:speechbrain.utils.fetching:Fetch classifier.ckpt: Using symlink found at '/content/pretrained_models/spkrec-ecapa/classifier.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["classifier"] = /content/pretrained_models/spkrec-ecapa/classifier.ckpt
# INFO:speechbrain.utils.fetching:Fetch label_encoder.txt: Using symlink found at '/content/pretrained_models/spkrec-ecapa/label_encoder.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["label_encoder"] = /content/pretrained_models/spkrec-ecapa/label_encoder.ckpt
# INFO:speechbrain.utils.parameter_transfer:Loading pretrained files for: embedding_model, mean_var_norm_emb, classifier, label_encoder
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): embedding_model -> /content/pretrained_models/spkrec-ecapa/embedding_model.ckpt
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): mean_var_norm_emb -> /content/pretrained_models/spkrec-ecapa/mean_var_norm_emb.ckpt
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): classifier -> /content/pretrained_models/spkrec-ecapa/classifier.ckpt
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): label_encoder -> /content/pretrained_models/spkrec-ecapa/label_encoder.ckpt
# DEBUG:speechbrain.dataio.encoder:Loaded categorical encoding from /content/pretrained_models/spkrec-ecapa/label_encoder.ckpt
# ✅ Score: 0.8681559562683105
# ✅ Joint Embedding Shape: torch.Size([1, 256])

# %% [markdown]
# 🎯 Goal:
# Fuse the 256-dim visual embedding and 192-dim audio embedding into a single 256-dim joint representation.

# %% [markdown]
# GMU Fusion Module Design

# %% [markdown]
# Equation:
# Let:
#
# v = visual embedding [256]
# a = audio embedding [192]
# We first project a → 256, then compute:

# %% [markdown]
# z = sigmoid(Wz_v * v + Wz_a * a)
# h = z ⊙ tanh(Wv * v) + (1 - z) ⊙ tanh(Wa * a)

# %% [markdown]
# Test in

# %%
# !python /content/drive/MyDrive/biovid_dual_auth/updated_pipeline/train_crossval.py
# Out:
# /content/drive/MyDrive/biovid_dual_auth/updated_pipeline/models/audio_encoder.py:5: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   from speechbrain.pretrained import SpeakerRecognition
# Using device: cuda
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R3D_18_Weights.KINETICS400_V1`. You can also use `weights=R3D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/autocast.py:188: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   wrapped_fwd = torch.cuda.amp.custom_fwd(fwd, cast_inputs=cast_inputs)
# Fold 0 - Epoch 1: 100% 38/38 [00:12<00:00,  3.03it/s]
# Fold 0 - Epoch 1: Val Acc=0.5101, EER=0.4855
# Fold 0 - Epoch 2: 100% 38/38 [00:11<00:00,  3.38it/s]
# Fold 0 - Epoch 2: Val Acc=0.5839, EER=0.4157
# Fold 0 - Epoch 3: 100% 38/38 [00:14<00:00,  2.64it/s]
# Fold 0 - Epoch 3: Val Acc=0.6376, EER=0.3592
# Fold 0 - Epoch 4: 100% 38/38 [00:14<00:00,  2.63it/s]
# Fold 0 - Epoch 4: Val Acc=0.6443, EER=0.3569
# Fold 0 - Epoch 5: 100% 38/38 [00:14<00:00,  2.65it/s]
# Fold 0 - Epoch 5: Val Acc=0.6577, EER=0.3427
# Fold 0 - Epoch 6: 100% 38/38 [00:14<00:00,  2.66it/s]
# Fold 0 - Epoch 6: Val Acc=0.6577, EER=0.3427
# Fold 0 - Epoch 7: 100% 38/38 [00:11<00:00,  3.35it/s]
# Fold 0 - Epoch 7: Val Acc=0.6980, EER=0.3035
# Fold 0 - Epoch 8: 100% 38/38 [00:14<00:00,  2.63it/s]
# Fold 0 - Epoch 8: Val Acc=0.6711, EER=0.3286
# Fold 0 - Epoch 9: 100% 38/38 [00:11<00:00,  3.40it/s]
# Fold 0 - Epoch 9: Val Acc=0.6577, EER=0.3459
# Fold 0 - Epoch 10: 100% 38/38 [00:11<00:00,  3.40it/s]
# Fold 0 - Epoch 10: Val Acc=0.7047, EER=0.2949
# Fold 0 - Epoch 11: 100% 38/38 [00:14<00:00,  2.62it/s]
# Fold 0 - Epoch 11: Val Acc=0.6711, EER=0.3286
# Fold 0 - Epoch 12: 100% 38/38 [00:11<00:00,  3.40it/s]
# Fold 0 - Epoch 12: Val Acc=0.7047, EER=0.2980
# Fold 0 - Epoch 13: 100% 38/38 [00:11<00:00,  3.38it/s]
# Fold 0 - Epoch 13: Val Acc=0.6846, EER=0.3145
# Fold 0 - Epoch 14: 100% 38/38 [00:11<00:00,  3.42it/s]
# Fold 0 - Epoch 14: Val Acc=0.7047, EER=0.2949
# Fold 0 - Epoch 15: 100% 38/38 [00:11<00:00,  3.42it/s]
# Fold 0 - Epoch 15: Val Acc=0.6913, EER=0.3090
# Fold 0 - Epoch 16: 100% 38/38 [00:11<00:00,  3.44it/s]
# Fold 0 - Epoch 16: Val Acc=0.6980, EER=0.3004
# Fold 0 - Epoch 17: 100% 38/38 [00:11<00:00,  3.39it/s]
# Fold 0 - Epoch 17: Val Acc=0.7047, EER=0.2949
# Fold 0 - Epoch 18: 100% 38/38 [00:10<00:00,  3.46it/s]
# Fold 0 - Epoch 18: Val Acc=0.7047, EER=0.2980
# Fold 0 - Epoch 19: 100% 38/38 [00:11<00:00,  3.40it/s]
# Fold 0 - Epoch 19: Val Acc=0.7315, EER=0.2698
# Fold 0 - Epoch 20: 100% 38/38 [00:14<00:00,  2.68it/s]
# Fold 0 - Epoch 20: Val Acc=0.6711, EER=0.3255
# Fold 0 - Epoch 21: 100% 38/38 [00:11<00:00,  3.42it/s]
# Fold 0 - Epoch 21: Val Acc=0.7047, EER=0.2949
# Fold 0 - Epoch 22: 100% 38/38 [00:11<00:00,  3.42it/s]
# Fold 0 - Epoch 22: Val Acc=0.6913, EER=0.3090
# Fold 0 - Epoch 23: 100% 38/38 [00:11<00:00,  3.42it/s]
# Fold 0 - Epoch 23: Val Acc=0.6980, EER=0.3004
# Fold 0 - Epoch 24: 100% 38/38 [00:11<00:00,  3.43it/s]
# Fold 0 - Epoch 24: Val Acc=0.6913, EER=0.3090
# Fold 0 - Epoch 25: 100% 38/38 [00:11<00:00,  3.43it/s]
# Fold 0 - Epoch 25: Val Acc=0.7181, EER=0.2808
# Fold 0 - Epoch 26: 100% 38/38 [00:11<00:00,  3.40it/s]
# Fold 0 - Epoch 26: Val Acc=0.7047, EER=0.2918
# Fold 0 - Epoch 27: 100% 38/38 [00:11<00:00,  3.42it/s]
# Fold 0 - Epoch 27: Val Acc=0.7315, EER=0.2667
# Fold 0 - Epoch 28: 100% 38/38 [00:13<00:00,  2.78it/s]
# Fold 0 - Epoch 28: Val Acc=0.6913, EER=0.3028
# Fold 0 - Epoch 29: 100% 38/38 [00:10<00:00,  3.47it/s]
# Fold 0 - Epoch 29: Val Acc=0.7383, EER=0.2612
# Fold 0 - Epoch 30: 100% 38/38 [00:14<00:00,  2.66it/s]
# Fold 0 - Epoch 30: Val Acc=0.7248, EER=0.2753
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R3D_18_Weights.KINETICS400_V1`. You can also use `weights=R3D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Fold 1 - Epoch 1: 100% 38/38 [00:10<00:00,  3.48it/s]
# Fold 1 - Epoch 1: Val Acc=0.5570, EER=0.4410
# Fold 1 - Epoch 2: 100% 38/38 [00:11<00:00,  3.43it/s]
# Fold 1 - Epoch 2: Val Acc=0.6174, EER=0.3823
# Fold 1 - Epoch 3: 100% 38/38 [00:11<00:00,  3.41it/s]
# Fold 1 - Epoch 3: Val Acc=0.6309, EER=0.3686
# Fold 1 - Epoch 4: 100% 38/38 [00:13<00:00,  2.74it/s]
# Fold 1 - Epoch 4: Val Acc=0.6376, EER=0.3628
# Fold 1 - Epoch 5: 100% 38/38 [00:13<00:00,  2.73it/s]
# Fold 1 - Epoch 5: Val Acc=0.6711, EER=0.3295
# Fold 1 - Epoch 6: 100% 38/38 [00:12<00:00,  3.08it/s]
# Fold 1 - Epoch 6: Val Acc=0.6711, EER=0.3295
# Fold 1 - Epoch 7: 100% 38/38 [00:11<00:00,  3.43it/s]
# Fold 1 - Epoch 7: Val Acc=0.6644, EER=0.3353
# Fold 1 - Epoch 8: 100% 38/38 [00:10<00:00,  3.46it/s]
# Fold 1 - Epoch 8: Val Acc=0.6711, EER=0.3295
# Fold 1 - Epoch 9: 100% 38/38 [00:11<00:00,  3.45it/s]
# Fold 1 - Epoch 9: Val Acc=0.6644, EER=0.3353
# Fold 1 - Epoch 10: 100% 38/38 [00:11<00:00,  3.43it/s]
# Fold 1 - Epoch 10: Val Acc=0.6711, EER=0.3273
# Fold 1 - Epoch 11: 100% 38/38 [00:13<00:00,  2.76it/s]
# Fold 1 - Epoch 11: Val Acc=0.6644, EER=0.3353
# Fold 1 - Epoch 12: 100% 38/38 [00:11<00:00,  3.43it/s]
# Fold 1 - Epoch 12: Val Acc=0.6711, EER=0.3295
# Fold 1 - Epoch 13: 100% 38/38 [00:11<00:00,  3.45it/s]
# Fold 1 - Epoch 13: Val Acc=0.6711, EER=0.3295
# Fold 1 - Epoch 14: 100% 38/38 [00:11<00:00,  3.45it/s]
# Fold 1 - Epoch 14: Val Acc=0.6846, EER=0.3178
# Fold 1 - Epoch 15: 100% 38/38 [00:11<00:00,  3.43it/s]
# Fold 1 - Epoch 15: Val Acc=0.6644, EER=0.3353
# Fold 1 - Epoch 16: 100% 38/38 [00:11<00:00,  3.43it/s]
# Fold 1 - Epoch 16: Val Acc=0.6644, EER=0.3353
# Fold 1 - Epoch 17: 100% 38/38 [00:10<00:00,  3.48it/s]
# Fold 1 - Epoch 17: Val Acc=0.6913, EER=0.3099
# Fold 1 - Epoch 18: 100% 38/38 [00:14<00:00,  2.65it/s]
# Fold 1 - Epoch 18: Val Acc=0.6980, EER=0.3020
# Fold 1 - Epoch 19: 100% 38/38 [00:14<00:00,  2.64it/s]
# Fold 1 - Epoch 19: Val Acc=0.6846, EER=0.3157
# Fold 1 - Epoch 20: 100% 38/38 [00:11<00:00,  3.27it/s]
# Fold 1 - Epoch 20: Val Acc=0.7047, EER=0.2961
# Fold 1 - Epoch 21: 100% 38/38 [00:14<00:00,  2.63it/s]
# Fold 1 - Epoch 21: Val Acc=0.7047, EER=0.2940
# Fold 1 - Epoch 22: 100% 38/38 [00:14<00:00,  2.57it/s]
# Fold 1 - Epoch 22: Val Acc=0.6980, EER=0.3020
# Fold 1 - Epoch 23: 100% 38/38 [00:11<00:00,  3.26it/s]
# Fold 1 - Epoch 23: Val Acc=0.6711, EER=0.3295
# Fold 1 - Epoch 24: 100% 38/38 [00:11<00:00,  3.25it/s]
# Fold 1 - Epoch 24: Val Acc=0.6913, EER=0.3078
# Fold 1 - Epoch 25: 100% 38/38 [00:11<00:00,  3.26it/s]
# Fold 1 - Epoch 25: Val Acc=0.6980, EER=0.3020
# Fold 1 - Epoch 26: 100% 38/38 [00:11<00:00,  3.26it/s]
# Fold 1 - Epoch 26: Val Acc=0.6644, EER=0.3353
# Fold 1 - Epoch 27: 100% 38/38 [00:11<00:00,  3.27it/s]
# Fold 1 - Epoch 27: Val Acc=0.6846, EER=0.3157
# Fold 1 - Epoch 28: 100% 38/38 [00:11<00:00,  3.26it/s]
# Fold 1 - Epoch 28: Val Acc=0.6779, EER=0.3215
# Fold 1 - Epoch 29: 100% 38/38 [00:11<00:00,  3.27it/s]
# Fold 1 - Epoch 29: Val Acc=0.6846, EER=0.3157
# Fold 1 - Epoch 30: 100% 38/38 [00:11<00:00,  3.22it/s]
# Fold 1 - Epoch 30: Val Acc=0.6846, EER=0.3157
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R3D_18_Weights.KINETICS400_V1`. You can also use `weights=R3D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Fold 2 - Epoch 1: 100% 38/38 [00:11<00:00,  3.25it/s]
# Fold 2 - Epoch 1: Val Acc=0.6107, EER=0.3886
# Fold 2 - Epoch 2: 100% 38/38 [00:11<00:00,  3.24it/s]
# Fold 2 - Epoch 2: Val Acc=0.6443, EER=0.3548
# Fold 2 - Epoch 3: 100% 38/38 [00:14<00:00,  2.57it/s]
# Fold 2 - Epoch 3: Val Acc=0.6846, EER=0.3122
# Fold 2 - Epoch 4: 100% 38/38 [00:14<00:00,  2.60it/s]
# Fold 2 - Epoch 4: Val Acc=0.6913, EER=0.3067
# Fold 2 - Epoch 5: 100% 38/38 [00:14<00:00,  2.62it/s]
# Fold 2 - Epoch 5: Val Acc=0.6779, EER=0.3209
# Fold 2 - Epoch 6: 100% 38/38 [00:11<00:00,  3.39it/s]
# Fold 2 - Epoch 6: Val Acc=0.7181, EER=0.2817
# Fold 2 - Epoch 7: 100% 38/38 [00:14<00:00,  2.69it/s]
# Fold 2 - Epoch 7: Val Acc=0.7047, EER=0.2959
# Fold 2 - Epoch 8: 100% 38/38 [00:11<00:00,  3.43it/s]
# Fold 2 - Epoch 8: Val Acc=0.7248, EER=0.2762
# Fold 2 - Epoch 9: 100% 38/38 [00:13<00:00,  2.72it/s]
# Fold 2 - Epoch 9: Val Acc=0.7248, EER=0.2762
# Fold 2 - Epoch 10: 100% 38/38 [00:11<00:00,  3.40it/s]
# Fold 2 - Epoch 10: Val Acc=0.7181, EER=0.2817
# Fold 2 - Epoch 11: 100% 38/38 [00:11<00:00,  3.38it/s]
# Fold 2 - Epoch 11: Val Acc=0.7383, EER=0.2620
# Fold 2 - Epoch 12: 100% 38/38 [00:14<00:00,  2.67it/s]
# Fold 2 - Epoch 12: Val Acc=0.7383, EER=0.2620
# Fold 2 - Epoch 13: 100% 38/38 [00:11<00:00,  3.41it/s]
# Fold 2 - Epoch 13: Val Acc=0.7181, EER=0.2817
# Fold 2 - Epoch 14: 100% 38/38 [00:11<00:00,  3.40it/s]
# Fold 2 - Epoch 14: Val Acc=0.7181, EER=0.2817
# Fold 2 - Epoch 15: 100% 38/38 [00:11<00:00,  3.40it/s]
# Fold 2 - Epoch 15: Val Acc=0.7114, EER=0.2871
# Fold 2 - Epoch 16: 100% 38/38 [00:11<00:00,  3.42it/s]
# Fold 2 - Epoch 16: Val Acc=0.7315, EER=0.2708
# Fold 2 - Epoch 17: 100% 38/38 [00:11<00:00,  3.39it/s]
# Fold 2 - Epoch 17: Val Acc=0.7315, EER=0.2708
# Fold 2 - Epoch 18: 100% 38/38 [00:11<00:00,  3.39it/s]
# Fold 2 - Epoch 18: Val Acc=0.7450, EER=0.2532
# Fold 2 - Epoch 19: 100% 38/38 [00:14<00:00,  2.65it/s]
# Fold 2 - Epoch 19: Val Acc=0.7383, EER=0.2587
# Fold 2 - Epoch 20: 100% 38/38 [00:11<00:00,  3.40it/s]
# Fold 2 - Epoch 20: Val Acc=0.7383, EER=0.2587
# Fold 2 - Epoch 21: 100% 38/38 [00:11<00:00,  3.37it/s]
# Fold 2 - Epoch 21: Val Acc=0.7315, EER=0.2674
# Fold 2 - Epoch 22: 100% 38/38 [00:11<00:00,  3.39it/s]
# Fold 2 - Epoch 22: Val Acc=0.7315, EER=0.2674
# Fold 2 - Epoch 23: 100% 38/38 [00:11<00:00,  3.39it/s]
# Fold 2 - Epoch 23: Val Acc=0.7450, EER=0.2566
# Fold 2 - Epoch 24: 100% 38/38 [00:11<00:00,  3.39it/s]
# Fold 2 - Epoch 24: Val Acc=0.7114, EER=0.2904
# Fold 2 - Epoch 25: 100% 38/38 [00:11<00:00,  3.38it/s]
# Fold 2 - Epoch 25: Val Acc=0.7315, EER=0.2674
# Fold 2 - Epoch 26: 100% 38/38 [00:11<00:00,  3.39it/s]
# Fold 2 - Epoch 26: Val Acc=0.7181, EER=0.2817
# Fold 2 - Epoch 27: 100% 38/38 [00:11<00:00,  3.39it/s]
# Fold 2 - Epoch 27: Val Acc=0.7383, EER=0.2620
# Fold 2 - Epoch 28: 100% 38/38 [00:11<00:00,  3.41it/s]
# Fold 2 - Epoch 28: Val Acc=0.7248, EER=0.2762
# Fold 2 - Epoch 29: 100% 38/38 [00:11<00:00,  3.40it/s]
# Fold 2 - Epoch 29: Val Acc=0.7315, EER=0.2674
# Fold 2 - Epoch 30: 100% 38/38 [00:11<00:00,  3.41it/s]
# Fold 2 - Epoch 30: Val Acc=0.7315, EER=0.2674
#   fold  accuracy       eer     apcer     bpcer
# 0    0  0.724832  0.275294  0.274725  0.275862
# 1    1  0.684564  0.315707  0.313953  0.317460
# 2    2  0.731544  0.267449  0.271739  0.263158
# 3  avg  0.713647  0.286150  0.286806  0.285493

# %% [markdown]
# testset inference

# %%
# !python /content/drive/MyDrive/biovid_dual_auth/updated_pipeline/test_inference_vote.py
# Out:
# /content/drive/MyDrive/biovid_dual_auth/updated_pipeline/models/audio_encoder.py:5: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   from speechbrain.pretrained import SpeakerRecognition
# Using device: cuda
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R3D_18_Weights.KINETICS400_V1`. You can also use `weights=R3D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/autocast.py:188: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   wrapped_fwd = torch.cuda.amp.custom_fwd(fwd, cast_inputs=cast_inputs)
# ⚠️ Skipping 5_06_F (missing audio or frames)
# ⚠️ Skipping 5_09_F (missing audio or frames)
# ⚠️ Skipping 3_18_F (missing audio or frames)
# ⚠️ Skipping 5_04_F (missing audio or frames)
# ⚠️ Skipping 6_05_T (missing audio or frames)
# ⚠️ Skipping 25_06_F (missing audio or frames)
# ⚠️ Skipping 28_09_F (missing audio or frames)
# ⚠️ Skipping 18_04_F (missing audio or frames)
# ⚠️ Skipping 26_06_F (missing audio or frames)
# ⚠️ Skipping 32_06_T (missing audio or frames)
# FOLD 0 Test:  11% 21/193 [00:00<00:06, 26.48it/s]⚠️ Skipping 227b82f518c2b7ddf17fc54d6e14a46f7b5f7f0e (missing audio or frames)
# FOLD 0 Test:  18% 34/193 [00:01<00:05, 26.80it/s]⚠️ Skipping 5b56c762ca3f5fc52ff5bb98e35839ce074d3d91 (missing audio or frames)
# FOLD 0 Test:  31% 59/193 [00:02<00:04, 27.46it/s]⚠️ Skipping 5dc3c0975918077402b4dff77bb5f61134a85262 (missing audio or frames)
# FOLD 0 Test: 100% 193/193 [00:07<00:00, 27.27it/s]
# ⚠️ Skipping 5_06_F (missing audio or frames)
# ⚠️ Skipping 5_09_F (missing audio or frames)
# ⚠️ Skipping 3_18_F (missing audio or frames)
# ⚠️ Skipping 5_04_F (missing audio or frames)
# ⚠️ Skipping 6_05_T (missing audio or frames)
# ⚠️ Skipping 25_06_F (missing audio or frames)
# ⚠️ Skipping 28_09_F (missing audio or frames)
# ⚠️ Skipping 18_04_F (missing audio or frames)
# ⚠️ Skipping 26_06_F (missing audio or frames)
# ⚠️ Skipping 32_06_T (missing audio or frames)
# FOLD 1 Test:  11% 21/193 [00:00<00:06, 26.81it/s]⚠️ Skipping 227b82f518c2b7ddf17fc54d6e14a46f7b5f7f0e (missing audio or frames)
# FOLD 1 Test:  18% 34/193 [00:01<00:06, 25.99it/s]⚠️ Skipping 5b56c762ca3f5fc52ff5bb98e35839ce074d3d91 (missing audio or frames)
# FOLD 1 Test:  31% 59/193 [00:02<00:04, 28.26it/s]⚠️ Skipping 5dc3c0975918077402b4dff77bb5f61134a85262 (missing audio or frames)
# FOLD 1 Test: 100% 193/193 [00:06<00:00, 27.69it/s]
# ⚠️ Skipping 5_06_F (missing audio or frames)
# ⚠️ Skipping 5_09_F (missing audio or frames)
# ⚠️ Skipping 3_18_F (missing audio or frames)
# ⚠️ Skipping 5_04_F (missing audio or frames)
# ⚠️ Skipping 6_05_T (missing audio or frames)
# ⚠️ Skipping 25_06_F (missing audio or frames)
# ⚠️ Skipping 28_09_F (missing audio or frames)
# ⚠️ Skipping 18_04_F (missing audio or frames)
# ⚠️ Skipping 26_06_F (missing audio or frames)
# ⚠️ Skipping 32_06_T (missing audio or frames)
# FOLD 2 Test:  11% 21/193 [00:00<00:06, 26.02it/s]⚠️ Skipping 227b82f518c2b7ddf17fc54d6e14a46f7b5f7f0e (missing audio or frames)
# FOLD 2 Test:  18% 34/193 [00:01<00:05, 26.57it/s]⚠️ Skipping 5b56c762ca3f5fc52ff5bb98e35839ce074d3d91 (missing audio or frames)
# FOLD 2 Test:  31% 59/193 [00:02<00:04, 26.86it/s]⚠️ Skipping 5dc3c0975918077402b4dff77bb5f61134a85262 (missing audio or frames)
# FOLD 2 Test: 100% 193/193 [00:07<00:00, 27.25it/s]
# ✅ Submission saved to: /content/drive/MyDrive/biovid_dual_auth/updated_pipeline/submission/submission.json

# %%
import os
os.path.exists("/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/submission/submission.json")
# Out:
# True

# %%
import torch
import sys

sys.path.append("/content/drive/MyDrive/biovid_dual_auth/updated_pipeline")
from models.gmu_fusion import GMUFusion

# Dummy embeddings
v = torch.randn(1, 256)  # visual
a = torch.randn(1, 192)  # audio

fuser = GMUFusion()
fused = fuser(v, a)

print("Fused embedding shape:", fused.shape)  # [1, 256]
# Out:
# Fused embedding shape: torch.Size([1, 256])

# %% [markdown]
# Output Head (Classification + Embedding)

# %% [markdown]
# Build a head that:
#
# Outputs a binary prediction (genuine vs impostor)
# Produces a normalized 256-dim embedding for triplet loss

# %% [markdown]
# Test the Head

# %%
from models.output_head import OutputHead

head = OutputHead()
x = torch.randn(4, 256)  # batch of 4 fused embeddings
logits, emb = head(x)

print("Logits shape:", logits.shape)      # [4, 2]
print("Embedding shape:", emb.shape)      # [4, 256]
# Out:
# Logits shape: torch.Size([4, 2])
# Embedding shape: torch.Size([4, 256])

# %% [markdown]
# Create 3-Fold Splits Without Leakage

# %%
from sklearn.model_selection import KFold
from pathlib import Path

def create_3fold_user_split(root_dir):
    root = Path(root_dir)
    all_dirs = list(root.glob("*_*_*"))  # each video folder
    all_users = sorted(set([p.name.split("_")[0] for p in all_dirs]))

    user_to_label = {u: i for i, u in enumerate(all_users)}
    folds = []

    kf = KFold(n_splits=3, shuffle=True, random_state=42)
    for train_idx, val_idx in kf.split(all_users):
        train_users = set([all_users[i] for i in train_idx])
        val_users = set([all_users[i] for i in val_idx])

        train_videos = [str(p) for p in all_dirs if p.name.split("_")[0] in train_users]
        val_videos = [str(p) for p in all_dirs if p.name.split("_")[0] in val_users]

        folds.append((train_videos, val_videos))

    return folds, user_to_label

# %%
# !python /content/drive/MyDrive/biovid_dual_auth/updated_pipeline/train_crossval.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/train_crossval.py", line 14, in <module>
#     from datasets.biovid_dataset import BiovidDataset, create_3fold_user_split
# ModuleNotFoundError: No module named 'datasets.biovid_dataset'

# %%
import sys
sys.path.append("/content/drive/MyDrive/biovid_dual_auth/updated_pipeline")

# %%
import os

print("Folder contents:")
print(os.listdir("/content/drive/MyDrive/biovid_dual_auth/updated_pipeline"))

print("\nDatasets folder contents:")
print(os.listdir("/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/datasets"))
# Out:
# Folder contents:
# ['data', 'models', 'results', 'notebooks', 'scripts', 'datasets', '.ipynb_checkpoints', 'train_crossval.py']
#
# Datasets folder contents:
# ['biovid_dataset.py', '.ipynb_checkpoints', '__pycache__']

# %%
import sys
sys.path.append("/content/drive/MyDrive/biovid_dual_auth/updated_pipeline")

# %%
import importlib.util

# Point to the full path of your biovid_dataset.py file
file_path = "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/datasets/biovid_dataset.py"

# Load as a module
spec = importlib.util.spec_from_file_location("biovid_dataset", file_path)
biovid = importlib.util.module_from_spec(spec)
spec.loader.exec_module(biovid)

# Now access the classes/functions
BiovidDataset = biovid.BiovidDataset
create_3fold_user_split = biovid.create_3fold_user_split

print("✅ Import successful via importlib")
# Out:
# ✅ Import successful via importlib

# %%
# !python /content/drive/MyDrive/biovid_dual_auth/updated_pipeline/train_crossval.py
# Out:
# [🔁] Fold 0
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R3D_18_Weights.KINETICS400_V1`. You can also use `weights=R3D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/autocast.py:188: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   wrapped_fwd = torch.cuda.amp.custom_fwd(fwd, cast_inputs=cast_inputs)
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/train_crossval.py", line 235, in <module>
#     train_crossval("/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/data/processed/train")
#   File "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/train_crossval.py", line 204, in train_crossval
#     train_loss = train_one_epoch(model_parts, train_dl, optimizer, ce_loss, triplet_loss)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/train_crossval.py", line 77, in train_one_epoch
#     for batch in dataloader:
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 708, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 764, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/collate.py", line 398, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/collate.py", line 171, in collate
#     {
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/collate.py", line 172, in <dictcomp>
#     key: collate(
#          ^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/collate.py", line 155, in collate
#     return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/collate.py", line 272, in collate_tensor_fn
#     return torch.stack(batch, 0, out=out)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: stack expects each tensor to be equal size, but got [3, 30, 96, 96] at entry 0 and [3, 27, 96, 96] at entry 2

# %%
# !python /content/drive/MyDrive/biovid_dual_auth/updated_pipeline/evaluate_eer.py
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R3D_18_Weights.KINETICS400_V1`. You can also use `weights=R3D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/autocast.py:188: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   wrapped_fwd = torch.cuda.amp.custom_fwd(fwd, cast_inputs=cast_inputs)
# 🔎 Extracting enrollment embeddings for 299 videos...
# 100% 299/299 [00:17<00:00, 17.11it/s]
# 🎯 Evaluating on 148 validation videos...
# 100% 148/148 [00:07<00:00, 18.51it/s]
#
# ✅ EER: 0.5000
# ✅ AUC: 0.5000

# %%
# !python /content/drive/MyDrive/biovid_dual_auth/updated_pipeline/train_crossval.py
# Out:
# [🔁 Fold 0] Training on 305, validating on 152
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/train_crossval.py", line 149, in <module>
#     main()
#   File "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/train_crossval.py", line 146, in main
#     train_one_fold(fold_idx, train_videos, val_videos, user_to_label, output_dir)
#   File "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/train_crossval.py", line 39, in train_one_fold
#     train_sampler = TripletBatchSampler(train_dataset, batch_size=12)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/samplers/triplet_sampler.py", line 18, in __init__
#     label = dataset[idx]['user_label'].item()
#             ~~~~~~~~~~~~^^^^^^^^^^^^^^
# TypeError: tuple indices must be integers or slices, not str

# %%
# !python /content/drive/MyDrive/biovid_dual_auth/updated_pipeline/evaluate_eer.py
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R3D_18_Weights.KINETICS400_V1`. You can also use `weights=R3D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/autocast.py:188: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   wrapped_fwd = torch.cuda.amp.custom_fwd(fwd, cast_inputs=cast_inputs)
# 🔎 Extracting enrollment embeddings for 299 videos...
# 100% 299/299 [00:17<00:00, 17.27it/s]
# 🎯 Evaluating on 148 validation videos...
# 100% 148/148 [00:07<00:00, 19.41it/s]
#
# 👥 Users in both train and validation: 0 / 13
# 🎯 Matched validation samples: 0 / 148
#
# 📊 Cosine Similarity Stats
# Avg same-user similarity:   N/A
# Avg different-user similarity: N/A
#
# ❌ Not enough genuine/impostor samples for EER calculation.

# %%
# !python /content/drive/MyDrive/biovid_dual_auth/updated_pipeline/test_inference_vote.py
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R3D_18_Weights.KINETICS400_V1`. You can also use `weights=R3D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/autocast.py:188: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   wrapped_fwd = torch.cuda.amp.custom_fwd(fwd, cast_inputs=cast_inputs)
# 🔐 Enrolling users from train set...
#   0% 0/305 [00:00<?, ?it/s]❌ Skipping 1 due to error: expected str, bytes or os.PathLike object, not Tensor
#   0% 1/305 [00:00<01:11,  4.27it/s]❌ Skipping 3 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 3 due to error: expected str, bytes or os.PathLike object, not Tensor
#   1% 3/305 [00:00<00:33,  8.90it/s]❌ Skipping 2 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 6 due to error: expected str, bytes or os.PathLike object, not Tensor
#   2% 5/305 [00:00<00:24, 12.06it/s]❌ Skipping 3 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 3 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 3 due to error: expected str, bytes or os.PathLike object, not Tensor
#   3% 8/305 [00:00<00:18, 15.91it/s]❌ Skipping 3 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 3 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 1 due to error: expected str, bytes or os.PathLike object, not Tensor
#   4% 11/305 [00:00<00:15, 18.68it/s]❌ Skipping 2 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 4 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 4 due to error: expected str, bytes or os.PathLike object, not Tensor
#   5% 14/305 [00:00<00:14, 20.53it/s]❌ Skipping 4 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 3 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 2 due to error: expected str, bytes or os.PathLike object, not Tensor
#   6% 17/305 [00:00<00:13, 21.80it/s]❌ Skipping 2 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 4 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 3 due to error: expected str, bytes or os.PathLike object, not Tensor
#   7% 20/305 [00:01<00:12, 22.50it/s]❌ Skipping 2 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 3 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 3 due to error: expected str, bytes or os.PathLike object, not Tensor
#   8% 23/305 [00:01<00:12, 23.25it/s]❌ Skipping 2 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 4 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 4 due to error: expected str, bytes or os.PathLike object, not Tensor
� Skipping 28 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 29 due to error: expected str, bytes or os.PathLike object, not Tensor
#  57% 173/305 [00:07<00:06, 20.67it/s]❌ Skipping 26 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 26 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 18 due to error: expected str, bytes or os.PathLike object, not Tensor
#  58% 176/305 [00:07<00:06, 20.38it/s]❌ Skipping 26 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 19 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 28 due to error: expected str, bytes or os.PathLike object, not Tensor
#  59% 179/305 [00:07<00:05, 21.21it/s]❌ Skipping 19 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 18 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 29 due to error: expected str, bytes or os.PathLike object, not Tensor
#  60% 182/305 [00:07<00:06, 20.29it/s]❌ Skipping 19 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 20 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
#  61% 185/305 [00:08<00:05, 20.39it/s]❌ Skipping 20 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 26 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 26 due to error: expected str, bytes or os.PathLike object, not Tensor
#  62% 188/305 [00:08<00:05, 20.57it/s]❌ Skipping 27 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 28 due to error: expected str, bytes or os.PathLike object, not Tensor
#  63% 191/305 [00:08<00:05, 19.72it/s]❌ Skipping 27 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 26 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
#  64% 194/305 [00:08<00:05, 20.54it/s]❌ Skipping 28 due to error: Failed to open the input "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/data/processed/train/28_09_F/audio.wav" (No such file or directory).
# Exception raised from get_input_format_context at /__w/audio/audio/pytorch/audio/src/libtorio/ffmpeg/stream_reader/stream_reader.cpp:42 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x789905f6c1b6 in /usr/local/lib/python3.11/dist-packages/torch/lib/libc10.so)
# frame #1: c10::detail::torchCheckFail(char const*, char const*, unsigned int, std::string const&) + 0x64 (0x789905f15a76 in /usr/local/lib/python3.11/dist-packages/torch/lib/libc10.so)
# frame #2: <unknown function> + 0x42034 (0x7898828ca034 in /usr/local/lib/python3.11/dist-packages/torio/lib/libtorio_ffmpeg4.so)
# frame #3: torio::io::StreamingMediaDecoder::StreamingMediaDecoder(std::string const&, std::optional<std::string> const&, std::optional<std::map<std::string, std::string, std::less<std::string>, std::allocator<std::pair<std::string const, std::string> > > > const&) + 0x14 (0x7898828cca34 in /usr/local/lib/python3.11/dist-packages/torio/lib/libtorio_ffmpeg4.so)
# frame #4: <unknown function> + 0x3bfee (0x789828179fee in /usr/local/lib/python3.11/dist-packages/torio/lib/_torio_ffmpeg4.so)
# frame #5: <unknown function> + 0x330c7 (0x7898281710c7 in /usr/local/lib/python3.11/dist-packages/torio/lib/_torio_ffmpeg4.so)
# frame #6: python3() [0x55577b]
# <omitting python frames>
# frame #8: python3() [0x5855cd]
# frame #9: python3() [0x56e459]
# frame #10: python3() [0x52fc40]
# frame #11: <unknown function> + 0xfc6b (0x78990623cc6b in /usr/local/lib/python3.11/dist-packages/torchaudio/lib/_torchaudio.so)
# frame #15: python3() [0x56e0e6]
# frame #18: python3() [0x613cd4]
# frame #20: python3() [0x63415b]
# frame #21: python3() [0x6303b4]
# frame #22: python3() [0x6448f5]
# frame #27: <unknown function> + 0x29d90 (0x7899072cad90 in /lib/x86_64-linux-gnu/libc.so.6)
# frame #28: __libc_start_main + 0x80 (0x7899072cae40 in /lib/x86_64-linux-gnu/libc.so.6)
#
# ❌ Skipping 27 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 27 due to error: expected str, bytes or os.PathLike object, not Tensor
#  65% 197/305 [00:08<00:04, 21.70it/s]❌ Skipping 20 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 26 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 18 due to error: expected str, bytes or os.PathLike object, not Tensor
#  66% 200/305 [00:08<00:04, 21.83it/s]❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
#  67% 203/305 [00:09<00:05, 20.33it/s]❌ Skipping 19 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 19 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 19 due to error: expected str, bytes or os.PathLike object, not Tensor
#  68% 206/305 [00:09<00:04, 20.86it/s]❌ Skipping 28 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 20 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 18 due to error: Failed to open the input "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/data/processed/train/18_04_F/audio.wav" (No such file or directory).
# Exception raised from get_input_format_context at /__w/audio/audio/pytorch/audio/src/libtorio/ffmpeg/stream_reader/stream_reader.cpp:42 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x789905f6c1b6 in /usr/local/lib/python3.11/dist-packages/torch/lib/libc10.so)
# frame #1: c10::detail::torchCheckFail(char const*, char const*, unsigned int, std::string const&) + 0x64 (0x789905f15a76 in /usr/local/lib/python3.11/dist-packages/torch/lib/libc10.so)
# frame #2: <unknown function> + 0x42034 (0x7898828ca034 in /usr/local/lib/python3.11/dist-packages/torio/lib/libtorio_ffmpeg4.so)
# frame #3: torio::io::StreamingMediaDecoder::StreamingMediaDecoder(std::string const&, std::optional<std::string> const&, std::optional<std::map<std::string, std::string, std::less<std::string>, std::allocator<std::pair<std::string const, std::string> > > > const&) + 0x14 (0x7898828cca34 in /usr/local/lib/python3.11/dist-packages/torio/lib/libtorio_ffmpeg4.so)
# frame #4: <unknown function> + 0x3bfee (0x789828179fee in /usr/local/lib/python3.11/dist-packages/torio/lib/_torio_ffmpeg4.so)
# frame #5: <unknown function> + 0x330c7 (0x7898281710c7 in /usr/local/lib/python3.11/dist-packages/torio/lib/_torio_ffmpeg4.so)
# frame #6: python3() [0x55577b]
# <omitting python frames>
# frame #8: python3() [0x5855cd]
# frame #9: python3() [0x56e459]
# frame #10: python3() [0x52fc40]
# frame #11: <unknown function> + 0xfc6b (0x78990623cc6b in /usr/local/lib/python3.11/dist-packages/torchaudio/lib/_torchaudio.so)
# frame #15: python3() [0x56e0e6]
# frame #18: python3() [0x613cd4]
# frame #20: python3() [0x63415b]
# frame #21: python3() [0x6303b4]
# frame #22: python3() [0x6448f5]
# frame #27: <unknown function> + 0x29d90 (0x7899072cad90 in /lib/x86_64-linux-gnu/libc.so.6)
# frame #28: __libc_start_main + 0x80 (0x7899072cae40 in /lib/x86_64-linux-gnu/libc.so.6)
#
#  69% 209/305 [00:09<00:04, 22.08it/s]❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 29 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 26 due to error: expected str, bytes or os.PathLike object, not Tensor
#  70% 212/305 [00:09<00:04, 21.94it/s]❌ Skipping 18 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 28 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 20 due to error: expected str, bytes or os.PathLike object, not Tensor
#  70% 215/305 [00:09<00:04, 21.95it/s]❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 19 due to error: expected str, bytes or os.PathLike object, not Tensor
#  71% 218/305 [00:09<00:03, 22.20it/s]❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 29 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 19 due to error: expected str, bytes or os.PathLike object, not Tensor
#  72% 221/305 [00:09<00:04, 20.68it/s]❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 27 due to error: expected str, bytes or os.PathLike object, not Tensor
#  73% 224/305 [00:09<00:03, 21.07it/s]❌ Skipping 28 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 20 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 20 due to error: expected str, bytes or os.PathLike object, not Tensor
#  74% 227/305 [00:10<00:03, 21.56it/s]❌ Skipping 18 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 20 due to error: expected str, bytes or os.PathLike object, not Tensor
#  75% 230/305 [00:10<00:03, 21.67it/s]❌ Skipping 18 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 27 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 27 due to error: expected str, bytes or os.PathLike object, not Tensor
#  76% 233/305 [00:10<00:03, 21.81it/s]❌ Skipping 28 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 26 due to error: Failed to open the input "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/data/processed/train/26_06_F/audio.wav" (No such file or directory).
# Exception raised from get_input_format_context at /__w/audio/audio/pytorch/audio/src/libtorio/ffmpeg/stream_reader/stream_reader.cpp:42 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x789905f6c1b6 in /usr/local/lib/python3.11/dist-packages/torch/lib/libc10.so)
# frame #1: c10::detail::torchCheckFail(char const*, char const*, unsigned int, std::string const&) + 0x64 (0x789905f15a76 in /usr/local/lib/python3.11/dist-packages/torch/lib/libc10.so)
# frame #2: <unknown function> + 0x42034 (0x7898828ca034 in /usr/local/lib/python3.11/dist-packages/torio/lib/libtorio_ffmpeg4.so)
# frame #3: torio::io::StreamingMediaDecoder::StreamingMediaDecoder(std::string const&, std::optional<std::string> const&, std::optional<std::map<std::string, std::string, std::less<std::string>, std::allocator<std::pair<std::string const, std::string> > > > const&) + 0x14 (0x7898828cca34 in /usr/local/lib/python3.11/dist-packages/torio/lib/libtorio_ffmpeg4.so)
# frame #4: <unknown function> + 0x3bfee (0x789828179fee in /usr/local/lib/python3.11/dist-packages/torio/lib/_torio_ffmpeg4.so)
# frame #5: <unknown function> + 0x330c7 (0x7898281710c7 in /usr/local/lib/python3.11/dist-packages/torio/lib/_torio_ffmpeg4.so)
# frame #6: python3() [0x55577b]
# <omitting python frames>
# frame #8: python3() [0x5855cd]
# frame #9: python3() [0x56e459]
# frame #10: python3() [0x52fc40]
# frame #11: <unknown function> + 0xfc6b (0x78990623cc6b in /usr/local/lib/python3.11/dist-packages/torchaudio/lib/_torchaudio.so)
# frame #15: python3() [0x56e0e6]
# frame #18: python3() [0x613cd4]
# frame #20: python3() [0x63415b]
# frame #21: python3() [0x6303b4]
# frame #22: python3() [0x6448f5]
# frame #27: <unknown function> + 0x29d90 (0x7899072cad90 in /lib/x86_64-linux-gnu/libc.so.6)
# frame #28: __libc_start_main + 0x80 (0x7899072cae40 in /lib/x86_64-linux-gnu/libc.so.6)
#
#  77% 236/305 [00:10<00:03, 22.81it/s]❌ Skipping 22 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 29 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 18 due to error: expected str, bytes or os.PathLike object, not Tensor
#  78% 239/305 [00:10<00:03, 20.30it/s]❌ Skipping 19 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 35 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 30 due to error: expected str, bytes or os.PathLike object, not Tensor
#  79% 242/305 [00:10<00:03, 20.92it/s]❌ Skipping 36 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 29 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 36 due to error: expected str, bytes or os.PathLike object, not Tensor
#  80% 245/305 [00:10<00:02, 21.11it/s]❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 38 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 35 due to error: expected str, bytes or os.PathLike object, not Tensor
#  81% 248/305 [00:11<00:02, 21.15it/s]❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 36 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 35 due to error: expected str, bytes or os.PathLike object, not Tensor
#  82% 251/305 [00:11<00:02, 21.68it/s]❌ Skipping 30 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 29 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
#  83% 254/305 [00:11<00:02, 22.30it/s]❌ Skipping 36 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 30 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
#  84% 257/305 [00:11<00:02, 22.72it/s]❌ Skipping 35 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 38 due to error: expected str, bytes or os.PathLike object, not Tensor
#  85% 260/305 [00:11<00:01, 23.10it/s]❌ Skipping 29 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 30 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 36 due to error: expected str, bytes or os.PathLike object, not Tensor
#  86% 263/305 [00:11<00:01, 23.58it/s]❌ Skipping 38 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
#  87% 266/305 [00:11<00:01, 20.64it/s]❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 36 due to error: expected str, bytes or os.PathLike object, not Tensor
#  88% 269/305 [00:12<00:01, 20.17it/s]❌ Skipping 30 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 29 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
#  89% 272/305 [00:12<00:01, 21.07it/s]❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 36 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 30 due to error: expected str, bytes or os.PathLike object, not Tensor
#  90% 275/305 [00:12<00:01, 21.81it/s]❌ Skipping 36 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 35 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 30 due to error: expected str, bytes or os.PathLike object, not Tensor
#  91% 278/305 [00:12<00:01, 22.41it/s]❌ Skipping 38 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 38 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 35 due to error: expected str, bytes or os.PathLike object, not Tensor
#  92% 281/305 [00:12<00:01, 22.59it/s]❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
#  93% 284/305 [00:12<00:00, 23.03it/s]❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 38 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 30 due to error: expected str, bytes or os.PathLike object, not Tensor
#  94% 287/305 [00:12<00:00, 23.23it/s]❌ Skipping 36 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 30 due to error: expected str, bytes or os.PathLike object, not Tensor
#  95% 290/305 [00:12<00:00, 23.36it/s]❌ Skipping 38 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 35 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 38 due to error: expected str, bytes or os.PathLike object, not Tensor
#  96% 293/305 [00:13<00:00, 23.49it/s]❌ Skipping 35 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 30 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
#  97% 296/305 [00:13<00:00, 23.53it/s]❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 36 due to error: expected str, bytes or os.PathLike object, not Tensor
#  98% 299/305 [00:13<00:00, 22.08it/s]❌ Skipping 38 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 32 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 35 due to error: expected str, bytes or os.PathLike object, not Tensor
#  99% 302/305 [00:13<00:00, 21.86it/s]❌ Skipping 32 due to error: Failed to open the input "/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/data/processed/train/32_06_T/audio.wav" (No such file or directory).
# Exception raised from get_input_format_context at /__w/audio/audio/pytorch/audio/src/libtorio/ffmpeg/stream_reader/stream_reader.cpp:42 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x789905f6c1b6 in /usr/local/lib/python3.11/dist-packages/torch/lib/libc10.so)
# frame #1: c10::detail::torchCheckFail(char const*, char const*, unsigned int, std::string const&) + 0x64 (0x789905f15a76 in /usr/local/lib/python3.11/dist-packages/torch/lib/libc10.so)
# frame #2: <unknown function> + 0x42034 (0x7898828ca034 in /usr/local/lib/python3.11/dist-packages/torio/lib/libtorio_ffmpeg4.so)
# frame #3: torio::io::StreamingMediaDecoder::StreamingMediaDecoder(std::string const&, std::optional<std::string> const&, std::optional<std::map<std::string, std::string, std::less<std::string>, std::allocator<std::pair<std::string const, std::string> > > > const&) + 0x14 (0x7898828cca34 in /usr/local/lib/python3.11/dist-packages/torio/lib/libtorio_ffmpeg4.so)
# frame #4: <unknown function> + 0x3bfee (0x789828179fee in /usr/local/lib/python3.11/dist-packages/torio/lib/_torio_ffmpeg4.so)
# frame #5: <unknown function> + 0x330c7 (0x7898281710c7 in /usr/local/lib/python3.11/dist-packages/torio/lib/_torio_ffmpeg4.so)
# frame #6: python3() [0x55577b]
# <omitting python frames>
# frame #8: python3() [0x5855cd]
# frame #9: python3() [0x56e459]
# frame #10: python3() [0x52fc40]
# frame #11: <unknown function> + 0xfc6b (0x78990623cc6b in /usr/local/lib/python3.11/dist-packages/torchaudio/lib/_torchaudio.so)
# frame #15: python3() [0x56e0e6]
# frame #18: python3() [0x613cd4]
# frame #20: python3() [0x63415b]
# frame #21: python3() [0x6303b4]
# frame #22: python3() [0x6448f5]
# frame #27: <unknown function> + 0x29d90 (0x7899072cad90 in /lib/x86_64-linux-gnu/libc.so.6)
# frame #28: __libc_start_main + 0x80 (0x7899072cae40 in /lib/x86_64-linux-gnu/libc.so.6)
#
# ❌ Skipping 38 due to error: expected str, bytes or os.PathLike object, not Tensor
# ❌ Skipping 35 due to error: expected str, bytes or os.PathLike object, not Tensor
# 100% 305/305 [00:13<00:00, 22.39it/s]
#   0% 0/193 [00:00<?, ?it/s]❌ Error processing 000c1f5bc01f4a36968fa1275f468bb772e296ab: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 0025d92127245cfbb312dfabae3f231c92e0ee5b: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 02ab8526830689bd6a372c4d55a544c545c0915f: expected str, bytes or os.PathLike object, not Tensor
#   2% 3/193 [00:00<00:09, 20.68it/s]❌ Error processing 06d3a937a342b2f6947004e5237ae568db9eb607: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 087afdd82862f967a8cc79e84aee9a79dd5b06ce: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 0bdea3782e6ac6a54e4442f16cbd5c1517d37748: expected str, bytes or os.PathLike object, not Tensor
#   3% 6/193 [00:00<00:08, 22.34it/s]❌ Error processing 0d3b47537c9ef35823a51a9869298b1d4efa1baa: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 109242d0f1875a7fc06971bde4cf3be6afebc699: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 129d7d737ecc72bcd37ab5053e7f46112d4caff2: expected str, bytes or os.PathLike object, not Tensor
#   5% 9/193 [00:00<00:08, 22.92it/s]❌ Error processing 16bcaed40c9667f2c9930c0701f5f74696a21f94: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 17afa821da958310b2a67000aad795210f927df3: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 1afb07736d58c8b2d9f25198edf5592e5cfdffb7: expected str, bytes or os.PathLike object, not Tensor
#   6% 12/193 [00:00<00:07, 23.27it/s]❌ Error processing 1c3ebfc6511745221971f180f51ac3dc5ae977ea: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 1c83e5c1c5eb621a439d84680d960e7e3de60186: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 1e8b62b6cdf9781e09053fd3034a4ff33a0a83e6: expected str, bytes or os.PathLike object, not Tensor
#   8% 15/193 [00:00<00:07, 23.43it/s]❌ Error processing 1fa842e9264964c91aa0944bb602af4bfcc37838: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 216f1a42ba02ee7b2e3f3cd76227b4bab9fb3928: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 21f6b59a3d988163eac769688d45d175358a8b16: expected str, bytes or os.PathLike object, not Tensor
#   9% 18/193 [00:00<00:07, 23.50it/s]❌ Error processing 220b13bec9c426998e97fa32ea85e8561e5b9879: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 226a60490c0a52ffd92178bbbdb31ae9326cd1a5: expected str, bytes or os.PathLike object, not Tensor
# ⚠️ Skipping 227b82f518c2b7ddf17fc54d6e14a46f7b5f7f0e: Missing frames/audio
# ❌ Error processing 23b4f39a99a26737936961d280ee8f9612f82fb6: expected str, bytes or os.PathLike object, not Tensor
#  11% 22/193 [00:00<00:06, 25.95it/s]❌ Error processing 2518e1425547cd787d05b7a6ceeaf7a60cbf5606: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 25442d1ca95614ee9e184f3ccba129c2bfec2ce9: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 26364fa714b036d5a591d2378162a11b2bf09bd3: expected str, bytes or os.PathLike object, not Tensor
#  13% 25/193 [00:01<00:06, 25.30it/s]❌ Error processing 269f36caf6aee2ad29f2c9f7689e179cb0a57361: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 288e21ddc04f577306be1fbe19e32a6c4b6659cf: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 29eafedfd41ec789ad877b471d76ba24072ec628: expected str, bytes or os.PathLike object, not Tensor
#  15% 28/193 [00:01<00:06, 24.66it/s]❌ Error processing 2b20ed1392731c2e8475a2581d416c3e082f01f5: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 30032e4b19bb2c1ec5ca23d10ef362737bdbd423: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 30686964d7717e514dc40c0624d45705da4f7b56: expected str, bytes or os.PathLike object, not Tensor
#  16% 31/193 [00:01<00:06, 24.41it/s]❌ Error processing 308b11039806e34f281f97f7c14db444ee86d666: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 31454cf4530ca3f2d848b09a825aef5c1e86e92b: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 31e3400cb00c4937acafc36109d2c699a73e5b4a: expected str, bytes or os.PathLike object, not Tensor
#  18% 34/193 [00:01<00:06, 24.12it/s]❌ Error processing 347b5da57d5e43ad2d15526c9a4f598a15b0ac88: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 34cfda95635a8c87728533dd3f69abaad2053685: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 36aef418e8b6a0bce9887d7c76ee37550c5a70a2: expected str, bytes or os.PathLike object, not Tensor
#  19% 37/193 [00:01<00:06, 24.11it/s]❌ Error processing 3856bc655ba7660be4f91348a9866af6b44d5550: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 39cda0c1cefe5c484342ea985e4207712a5bb924: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 3a6b913e03fc89a3fadce859ba6d2bbcf267e88f: expected str, bytes or os.PathLike object, not Tensor
#  21% 40/193 [00:01<00:06, 23.23it/s]❌ Error processing 3bab3668afc0a1d2027226cf4063d8930bda8716: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 3c1d43bf026ce50027a6d9f19205575af4a4bf26: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 3cf92d0a57efd35ff90bfc4cda56667388ece4e6: expected str, bytes or os.PathLike object, not Tensor
#  22% 43/193 [00:01<00:06, 23.37it/s]❌ Error processing 42e8f9fca4f016afc32a2d23c903a22e226807e8: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 43c58f36e0ad4d4eff97fd639631c0c918874bc5: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 43dc8f04eb25ddcb95524d01a2cba261221094e3: expected str, bytes or os.PathLike object, not Tensor
#  24% 46/193 [00:01<00:06, 23.30it/s]❌ Error processing 472fb261bdf77a2b89440aefb5c82f9891119ecb: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 474f467029cd9026b7508d5f7163111a2ad24d14: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 4be6f6e13ad663b65afc016c7eed0aa6aee7b9a8: expected str, bytes or os.PathLike object, not Tensor
#  25% 49/193 [00:02<00:06, 23.37it/s]❌ Error processing 4c4f3fd0443f5cae5444ae787c7098fd4447f79c: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 4c649f817f37d4f81fda67e3f2d16531f834a2ad: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 4c923261158915aa510e8224917007cc096bdf54: expected str, bytes or os.PathLike object, not Tensor
# ...
# ❌ Error processing 65ca8b0107656f311f136d780b3b8d40b41e40fe: expected str, bytes or os.PathLike object, not Tensor
#  36% 69/193 [00:02<00:04, 26.71it/s]❌ Error processing 66c6f8ad35b88703ac8d97192ae256333329fb68: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 68c6d381911a281e2c6e6b4afbdaf3dc739e0ae2: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 69d5d386f2765edaf6af7fa412fbd059a53a9222: expected str, bytes or os.PathLike object, not Tensor
#  37% 72/193 [00:02<00:04, 25.62it/s]❌ Error processing 6a7d095fd43bc2ec66ab65771885169526dbef2d: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 6c520333e583d7176778377c7ac848dc5cf11686: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 6d179cac2116bd533b89e80b96eb02ebfc64437d: expected str, bytes or os.PathLike object, not Tensor
#  39% 75/193 [00:03<00:04, 24.43it/s]❌ Error processing 6dcc7d6a8fd8b59eadcdc97523b164c02f018f3b: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 6f282c3f1f95fdd0c4f4d4bdd5a6403b722990af: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 6f87adad3adf4649ada71d27e59c781660914b03: expected str, bytes or os.PathLike object, not Tensor
#  40% 78/193 [00:03<00:04, 24.18it/s]❌ Error processing 6fdfee4bb3cd6f4dd399e8e94741e4c7973b56ed: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 71d323858d147078f1a4cb2ab09d28c0f9898b72: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 722c211e0ab69498cceed3185332d2333ee12966: expected str, bytes or os.PathLike object, not Tensor
#  42% 81/193 [00:03<00:04, 24.01it/s]❌ Error processing 743221218f18b7776992bf54625d6f5e671bcb0f: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 74c422402755812968acd75685c88b599e51eeca: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 7563a5d69091bf5c650d13ac06cfed89024377d3: expected str, bytes or os.PathLike object, not Tensor
#  44% 84/193 [00:03<00:04, 23.91it/s]❌ Error processing 77b62fd099e18c1d718406a2c627551f07438707: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 7a1085141fa98e082fcff3a689b37972e915142e: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 7a5166535f5bed65ef1934782fa3db42f1904ddd: expected str, bytes or os.PathLike object, not Tensor
#  45% 87/193 [00:03<00:04, 23.47it/s]❌ Error processing 7b38f307d2381ebd139114901e9fe8de1faffb42: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 7c942d514749e9e0be5dcf2219657dadfddb1078: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 7cb8807da0636940e0d6317654c4055c2044bf6d: expected str, bytes or os.PathLike object, not Tensor
#  47% 90/193 [00:03<00:04, 23.50it/s]❌ Error processing 8186fd72349f0b0239112ee41b1cbaa9a4ab9c61: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 82654a4692885ac6ad00de5ed66ae8e8a8030385: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 842c09dbffe61be2281023ade82f73eb45602aba: expected str, bytes or os.PathLike object, not Tensor
#  48% 93/193 [00:03<00:04, 23.59it/s]❌ Error processing 84ea630c4d99acbb17c752c830e89bc02e2b4d8d: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 8681083325766888c54bd220e0faa1e7eeea8d1d: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 86c116d392d0687abf614cbaef625c0049a5c852: expected str, bytes or os.PathLike object, not Tensor
#  50% 96/193 [00:04<00:04, 23.38it/s]❌ Error processing 871280a0dead09329d9a4ed254f324636041b532: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 8788be797482ded8643fdbf9523da944b1a1894c: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 87e825871a350ab327ccf270d11a4201aa20eb45: expected str, bytes or os.PathLike object, not Tensor
#  51% 99/193 [00:04<00:03, 23.51it/s]❌ Error processing 87f963bfa6e96c984f81845dc6f995dadefcb816: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 8917166df42f30b4bcf192dd909a465218f6b709: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 8a9048ed614a85061076f80fe8df30f2723e0fad: expected str, bytes or os.PathLike object, not Tensor
#  53% 102/193 [00:04<00:03, 23.52it/s]❌ Error processing 8af50b7d959f96019011e1f5936d98a14128bd02: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 8cd95ddc1d6b2a439a40b7ac402ff4d37043e00a: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 8e09af02aaa2daee38866c43f6a2325877c3125e: expected str, bytes or os.PathLike object, not Tensor
#  54% 105/193 [00:04<00:03, 23.40it/s]❌ Error processing 8e8965e4bd598b30fdbf98562f9febdc0f79aa82: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 8f5ba0fa0ac845097e64148d4995ec2e38bac762: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 91bb314b015bb10d591447e80ea03f9e3c9f0d23: expected str, bytes or os.PathLike object, not Tensor
#  56% 108/193 [00:04<00:03, 22.76it/s]❌ Error processing 9492d1b8c69d3110bf22314d0580551a932bd4cd: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 94aea0e1246e5c8d50f7e91db5583b9a2c9b32b4: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 959c9e6bba8dba1a520bc5c85ef25181b69fa7a8: expected str, bytes or os.PathLike object, not Tensor
#  58% 111/193 [00:04<00:03, 22.92it/s]❌ Error processing 98c9f85d919e9f81c788203d9a161b5dfaa15728: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 99c8b43dea49994566f03631555863d41c83d08d: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 9a996ea8390344591f239b3b5076d7fd16b35ab6: expected str, bytes or os.PathLike object, not Tensor
#  59% 114/193 [00:04<00:03, 23.10it/s]❌ Error processing 9deb35d1da33e263a9908d1d6f1a8c77c49eaa9c: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 9dfeffc94219f902a5f98203ceb036ec3328c2f6: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing 9e50e6c18f383c57ee1b63fc34ea50fb41d05dc6: expected str, bytes or os.PathLike object, not Tensor
#  61% 117/193 [00:04<00:03, 23.06it/s]❌ Error processing a06d34e702cbb9ede073b2586a4e6c98793f1f41: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing a08938c80afd1ac30bbf3f7af2f5ce16fd9d3b7d: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing a1c19c29467d5dd400ec4698438e907303595079: expected str, bytes or os.PathLike object, not Tensor
#  62% 120/193 [00:05<00:03, 23.19it/s]❌ Error processing a1f44582a1024a2a752b752afd2b68ad01aefeb7: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing a291c1e2b415d3196556c7cdc8349a7eb1d031fd: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing a4945e0ddd8bfddaaeeaff583607fcca9268d142: expected str, bytes or os.PathLike object, not Tensor
#  64% 123/193 [00:05<00:03, 23.27it/s]❌ Error processing a49b81f034900617f5a887232f1e8689d0497cf4: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing a502493ceac6c7941db0ff93a9039b7a5c9526d6: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing a5086847233bfe521269636aba714ff918527021: expected str, bytes or os.PathLike object, not Tensor
#  65% 126/193 [00:05<00:02, 23.36it/s]❌ Error processing a6ae5c8da12f5f71ed4424e8bffe77e949580f69: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing a9d6fb40920e445fcf6a7e87e996fc738e4996d0: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing adb7cb85bd98ea42922ed0026bdb79035d8214c3: expected str, bytes or os.PathLike object, not Tensor
#  67% 129/193 [00:05<00:02, 22.74it/s]❌ Error processing ae92b237420c46bc31317a348763c99e5ede3cd7: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing b0f0a9ddd22525fc83144d22e0a3ca08e4e23175: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing b1f00e97e62f7bb56e775e843f8fc43d98a43c45: expected str, bytes or os.PathLike object, not Tensor
#  68% 132/193 [00:05<00:02, 22.88it/s]❌ Error processing b323080abae6940358d698dffc81ce023e92f58b: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing b3a007522915adc7c3f759f098d6a040fbc24000: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing b68c150a494c42a950c996f841a35da014018546: expected str, bytes or os.PathLike object, not Tensor
#  70% 135/193 [00:05<00:02, 23.07it/s]❌ Error processing b8127c10bfb70f1960044a808cc40a269d560754: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing b9406463436b41a8f01682b328e8fc25ea8fe628: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing b9dd771e3e5e2dc38be537ff9dfec9e9cff605b1: expected str, bytes or os.PathLike object, not Tensor
#  72% 138/193 [00:05<00:02, 23.04it/s]❌ Error processing bc599ed2fa1b6db438e8b1b271829017e6998f54: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing c239205b26a01955d9d8f0a633421c1c692a3a6a: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing c384e750c7abb6fed84f7cd137aef318603cc1b3: expected str, bytes or os.PathLike object, not Tensor
#  73% 141/193 [00:05<00:02, 23.06it/s]❌ Error processing c4dac0c7e8a3962ad6afdb38a6686cbefc565d41: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing c64d29aa2ecd9554ddb3f7bb264b2f31c299bd25: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing c7574df955d5ca3a468315c10c5b783c4e02a4d8: expected str, bytes or os.PathLike object, not Tensor
#  75% 144/193 [00:06<00:02, 22.41it/s]❌ Error processing c805e4025395acad9530098f7c9cd485d4dfd762: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing c8153efb0950d81453f9a02d6f3e5aa888a51774: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing cacaa58290ae89cbebeac122241dbd221c72bcbb: expected str, bytes or os.PathLike object, not Tensor
#  76% 147/193 [00:06<00:02, 22.79it/s]❌ Error processing cb943c7b9ab739dc8a1b9c165ce58170600e0c5f: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing cd3eae51f50ebe7594815e1c84ea587e1a145abd: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing cda92d12f4043a733db507a4ccf16e67ee022551: expected str, bytes or os.PathLike object, not Tensor
#  78% 150/193 [00:06<00:01, 23.06it/s]❌ Error processing cefe86896a48ab490cff612db539baf7c52f2ff7: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing cf6bb6c25d5fdebfae79691324ba554c31fadc47: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing d06f3624f573ecefba09cf7eef0209b692e1b317: expected str, bytes or os.PathLike object, not Tensor
#  79% 153/193 [00:06<00:01, 23.09it/s]❌ Error processing d25567946ae922eb2b8680d1ec1df3d6f93a8474: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing d53dbb45993d309f253f0f5853e72397f0744573: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing d64bf336b6d3ebf7ff13847c9335c7ca81dae2e0: expected str, bytes or os.PathLike object, not Tensor
#  81% 156/193 [00:06<00:01, 23.20it/s]❌ Error processing d65c50ba825a7fbfff368ad729297931681441bb: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing d67f15e15168f57b6699c5755152800325c15da8: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing d791453c54adda389364be6002d1eb74ddda0cfc: expected str, bytes or os.PathLike object, not Tensor
#  82% 159/193 [00:06<00:01, 23.16it/s]❌ Error processing d806d4b061e4154c04dbabe1055c51fbacdeeec8: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing d971b03fb7ed6058a96ab2698f270343b8c9dcdd: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing dad26f624e3cef92ca1f961dad41f4d8d120c225: expected str, bytes or os.PathLike object, not Tensor
#  84% 162/193 [00:06<00:01, 23.32it/s]❌ Error processing dd8e557a4fda7c7096fed6c944a8dd65dd05d6cb: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing ddab2619a747519deb3e9c9b63a26b86cfc37c97: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing dde9e781346fa0c0eb8932e243b8709d52b2c280: expected str, bytes or os.PathLike object, not Tensor
#  85% 165/193 [00:06<00:01, 23.55it/s]❌ Error processing dec6ff8d5837be9d4f48a275b12f601df0404029: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing df6e35f13cf74be9d62cd25c4ef76df409a9f33d: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing dfbf337209a25640e717553a305245a53f79fcf5: expected str, bytes or os.PathLike object, not Tensor
#  87% 168/193 [00:07<00:01, 22.98it/s]❌ Error processing e174a7a1e3c19ab04a7404796d81869e091e5d45: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing e1ad319bb2d1aff61a2349e9ae769d64392f436f: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing e3f4fd71bb0dc7d0e68caaedfae1929f94736a2b: expected str, bytes or os.PathLike object, not Tensor
#  89% 171/193 [00:07<00:00, 22.80it/s]❌ Error processing e403d48e66140d1db6c65be3ea659684f5c179aa: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing e4175a8ef0521562b64524c0f6c9bc60556746d8: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing e7337d96ec7c76f9f634ec473f18ca9c5185d688: expected str, bytes or os.PathLike object, not Tensor
#  90% 174/193 [00:07<00:00, 23.00it/s]❌ Error processing e9086aa636047de880265e33f552de9dc8f993a5: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing ea0e87527a15942eba1e727ed4ec50353e708b34: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing efe5a46ecc53085d01f4c893ff52afc192519286: expected str, bytes or os.PathLike object, not Tensor
#  92% 177/193 [00:07<00:00, 22.49it/s]❌ Error processing f14804c4caf4659c43f5f5f610a57422db38da07: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing f21427ad07a90ff3762584086d44fc39773c0b2b: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing f32ec658c22797d1b447c82b0dea5b246534da7e: expected str, bytes or os.PathLike object, not Tensor
#  93% 180/193 [00:07<00:00, 22.05it/s]❌ Error processing f3ca416d795f8122aba175aeb62f9c0b74cc4529: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing f4414ad07664823dd7bfb7c14c18095924d24ea6: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing f685c67f8e356cb66ff33953a4975ff9c9a86948: expected str, bytes or os.PathLike object, not Tensor
#  95% 183/193 [00:07<00:00, 21.93it/s]❌ Error processing f75216a75ca11e5830b1522bada3ccac0d90c783: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing f7c77c2c26acb666134d557e69348c86e014eeaa: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing f828ccf7986cd08a912640f7166187f8e067179a: expected str, bytes or os.PathLike object, not Tensor
#  96% 186/193 [00:07<00:00, 21.95it/s]❌ Error processing f90b18833414dd4628092199b811794ac1ca5bed: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing fb24af2264a0a77b155917143acef01ea1907d2a: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing fc2ea233e1a0018ba4ea5705050f3ccc2bae7024: expected str, bytes or os.PathLike object, not Tensor
#  98% 189/193 [00:08<00:00, 22.16it/s]❌ Error processing fcfff124e6773cae0f565e5840cc8a9f58a02901: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing fe96618d734b64effb1c65ee8b4b9adbe4472786: expected str, bytes or os.PathLike object, not Tensor
# ❌ Error processing feede206e625e925e228da4c1ba09cdad565228f: expected str, bytes or os.PathLike object, not Tensor
#  99% 192/193 [00:08<00:00, 22.13it/s]❌ Error processing ff4d02e38c106eafe0d405faade4080bf628cf25: expected str, bytes or os.PathLike object, not Tensor
# 100% 193/193 [00:08<00:00, 23.37it/s]
# ✅ Saved 0 predictions to submission.json

# %%
# !pip install pydot
# !apt-get install graphviz
# Out:
# Requirement already satisfied: pydot in /usr/local/lib/python3.11/dist-packages (3.0.4)
# Requirement already satisfied: pyparsing>=3.0.9 in /usr/local/lib/python3.11/dist-packages (from pydot) (3.2.3)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
from keras.models import Model
from keras.layers import (Input, Conv2D, TimeDistributed, GlobalAveragePooling2D,
                          Bidirectional, GRU, Dense, Concatenate, Lambda, Multiply, Add)
from keras.utils import plot_model
import tensorflow as tf

# --- Visual Stream (per-frame Conv2D + GRU) ---
video_input = Input(shape=(30, 96, 96, 3), name='video_input')
x = TimeDistributed(Conv2D(32, (3, 3), padding='same', activation='relu'))(video_input)
x = TimeDistributed(GlobalAveragePooling2D())(x)
x = Bidirectional(GRU(128))(x)
visual_embedding = Dense(256, activation='relu', name='visual_fc')(x)

# --- Audio Stream ---
audio_input = Input(shape=(192,), name='audio_input')
audio_proj = Dense(256, activation='relu', name='audio_fc')(audio_input)

# --- GMU Fusion ---
concat = Concatenate(name='concat_audio_visual')([visual_embedding, audio_input])
z = Dense(256, activation='sigmoid', name='z_gate')(concat)

v_trans = Dense(256, activation='tanh', name='v_transform')(visual_embedding)
a_trans = Dense(256, activation='tanh', name='a_transform')(audio_proj)

z_inv = Lambda(lambda x: 1.0 - x, name='1_minus_z')(z)
zv = Multiply(name='zv')([z, v_trans])
za = Multiply(name='1mz_a')([z_inv, a_trans])
fused = Add(name='gmu_output')([zv, za])

# --- Output Head ---
classification_output = Dense(1, activation='sigmoid', name='classification')(fused)
triplet_embedding = Lambda(lambda x: tf.math.l2_normalize(x, axis=1), name='triplet_norm')(fused)

model = Model(inputs=[video_input, audio_input], outputs=[classification_output, triplet_embedding])

# Save the model diagram
plot_model(model, show_shapes=True, show_layer_names=True, to_file="biovid_model.png", dpi=96)

# %%
from keras.models import Model
from keras.layers import (Input, Conv2D, TimeDistributed, GlobalAveragePooling2D,
                          Bidirectional, GRU, Dense, Concatenate, Lambda, Multiply, Add)
from keras.utils import plot_model
import tensorflow as tf

# --- Visual Stream (per-frame Conv2D + GRU) ---
video_input = Input(shape=(30, 96, 96, 3), name='video_input')
x = TimeDistributed(Conv2D(32, (3, 3), padding='same', activation='relu'))(video_input)
x = TimeDistributed(GlobalAveragePooling2D())(x)
x = Bidirectional(GRU(128))(x)  # Output dim = 256
visual_embedding = Dense(256, activation='relu', name='visual_fc')(x)

# --- Audio Stream ---
audio_input = Input(shape=(192,), name='audio_input')  # ECAPA-TDNN embedding
audio_proj = Dense(256, activation='relu', name='audio_fc')(audio_input)

# --- GMU Fusion ---
concat = Concatenate(name='concat_audio_visual')([visual_embedding, audio_input])  # Note: original audio input, not projected
z = Dense(256, activation='sigmoid', name='z_gate')(concat)

v_trans = Dense(256, activation='tanh', name='v_transform')(visual_embedding)
a_trans = Dense(256, activation='tanh', name='a_transform')(audio_proj)

z_inv = Lambda(lambda x: 1.0 - x, name='1_minus_z')(z)
zv = Multiply(name='zv')([z, v_trans])
za = Multiply(name='1mz_a')([z_inv, a_trans])
fused = Add(name='gmu_output')([zv, za])  # Final joint embedding

# --- Output Head ---
classification_output = Dense(1, activation='sigmoid', name='classification')(fused)
triplet_embedding = Lambda(lambda x: tf.math.l2_normalize(x, axis=1), name='triplet_norm')(fused)

# --- Final Model ---
model = Model(inputs=[video_input, audio_input], outputs=[classification_output, triplet_embedding])

# --- Save Architecture Plot ---
plot_model(model, show_shapes=True, show_layer_names=True, to_file="biovid_model.png", dpi=96)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/MyDrive/biovid_dual_auth/updated_pipeline/results/biovid_results_20250620_0738.csv")  # use your actual path

plt.figure(figsize=(10, 5))
plt.plot(df['fold'], df['accuracy'], label='Accuracy')
plt.plot(df['fold'], df['eer'], label='EER')
plt.plot(df['fold'], df['apcer'], label='APCER')
plt.plot(df['fold'], df['bpcer'], label='BPCER')
plt.xlabel("Fold")
plt.ylabel("Metric")
plt.title("Performance Across 3-Fold Cross-Validation")
plt.legend()
plt.grid()
plt.savefig("training_metrics_curve.png")
plt.show()
